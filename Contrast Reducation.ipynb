# %%
import cv2
from matplotlib import pyplot as plt
import PIL as pillow
import numpy as np

# %%
image=cv2.imread('cvtest.jpg')
plt.imshow(image)

# %%
imagem=cv2.bitwise_not(image)
plt.imshow(imagem)
cv2.imwrite('cvtest.jpg',imagem)
# Out:
# True

# %%
from PIL import Image
from numpy import array
im1=Image.open('cvtest.jpg')
ar1=array(im1)
ar1
im2=Image.open('cvtest.jpg')
ar2=array(im2)
ar2
# Out:
# array([[[ 24, 122, 135],
#         [ 24, 122, 135],
#         [ 25, 123, 136],
#         ...,
#         [ 35, 127, 138],
#         [ 23, 113, 122],
#         [ 43, 131, 141]],
#
#        [[ 25, 123, 136],
#         [ 25, 123, 136],
#         [ 25, 123, 136],
#         ...,
#         [ 26, 119, 124],
#         [ 11, 102, 107],
#         [ 53, 141, 145]],
#
#        [[ 25, 123, 136],
#         [ 26, 124, 137],
#         [ 26, 124, 137],
#         ...,
#         [ 57, 147, 145],
#         [ 56, 145, 141],
#         [100, 185, 180]],
#
#        ...,
#
#        [[160, 220, 182],
#         [162, 224, 185],
#         [174, 236, 199],
#         ...,
#         [127, 207, 182],
#         [118, 200, 177],
#         [105, 187, 165]],
#
#        [[160, 220, 182],
#         [162, 224, 185],
#         [176, 238, 201],
#         ...,
#         [119, 201, 178],
#         [110, 194, 171],
#         [ 99, 184, 163]],
#
#        [[172, 234, 195],
#         [165, 229, 192],
#         [164, 228, 193],
#         ...,
#         [100, 185, 162],
#         [ 92, 180, 158],
#         [ 87, 176, 158]]], dtype=uint8)
