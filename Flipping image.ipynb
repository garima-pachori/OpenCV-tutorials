# %%
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("cvtest.jpg")
name='OpenCV Python Image'
plt.title(name)
plt.imshow(img)

# %%
horizontal_flip=cv2.flip(img,1)
name='OpenCV Flip Image Horiontally'
plt.title(name)
plt.imshow(horizontal_flip)

# %%
vertical_flip=cv2.flip(img,0)
name='OpenCV Python Flip Image Vertically'
plt.title(name)
plt.imshow(vertical_flip)

# %%
vertical_horizontal_flip=cv.flip(img,-1)
name='OpenCV Python Flip Image Both Vertically and Horizontally'
plt.title(name)
lt.imshow(vertical_hor)
